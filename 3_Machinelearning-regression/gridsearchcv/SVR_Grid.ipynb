# %%
#importing the Libraies
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Reading the Dataset
dataset = pd.read_csv('insurance_pre.csv')

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400     False        True
# 1      18  33.770         1   1725.55230      True       False
# 2      28  33.000         3   4449.46200      True       False
# 3      33  22.705         0  21984.47061      True       False
# 4      32  28.880         0   3866.85520      True       False
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830      True       False
# 1334   18  31.920         0   2205.98080     False       False
# 1335   18  36.850         0   1629.83350     False       False
# 1336   21  25.800         0   2007.94500     False       False
# 1337   61  29.070         0  29141.36030     False        True
#
# [1338 rows x 6 columns]

# %%
indep=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dep=dataset['charges']

# %%
#split into training set and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(indep, dep, test_size = 1/3, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
param_grid = {'kernel':['rbf','sigmoid','linear'],
              'C':[10,100,1000,2000,3000],'gamma':['auto','scale']} 



grid = GridSearchCV(SVR(), param_grid, refit = True, verbose = 3,n_jobs=-1) 
   
# fitting the model for grid search 
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [10, 100, 1000, 2000, 3000],
#                          'gamma': ['auto', 'scale'],
#                          'kernel': ['rbf', 'sigmoid', 'linear']},
#              verbose=3)

# %%
# print best parameter after tuning 
#print(grid.best_params_) 
re=grid.cv_results_
#print(re)
grid_predictions = grid.predict(indep) 
   
# print classification report 
from sklearn.metrics import r2_score
r_score=r2_score(dep,grid_predictions)

print("The R_score value for best parameter {}:".format(grid.best_params_),r_score)
# Out:
# C:\Anaconda\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(
# The R_score value for best parameter {'C': 3000, 'gamma': 'auto', 'kernel': 'rbf'}: -0.0664475726291498

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.066813      0.004072         0.038298        0.003873      10
# 1        0.078577      0.004362         0.011369        0.004279      10
# 2        0.054671      0.002756         0.009964        0.002701      10
# 3        0.068321      0.003201         0.038659        0.003391      10
# 4        0.073743      0.006340         0.012750        0.001013      10
# 5        0.049741      0.003306         0.010382        0.001299      10
# 6        0.067044      0.002187         0.041089        0.002093     100
# 7        0.074435      0.005271         0.014730        0.003262     100
# 8        0.064627      0.006161         0.008382        0.000737     100
# 9        0.072222      0.015154         0.040447        0.006507     100
# 10       0.076007      0.003084         0.014391        0.002746     100
# 11       0.058449      0.006090         0.008102        0.002827     100
# 12       0.082350      0.002270         0.039270        0.005683    1000
# 13       0.079930      0.008405         0.017432        0.001848    1000
# 14       0.076319      0.006141         0.007625        0.004895    1000
# 15       0.085528      0.003785         0.034620        0.004449    1000
# 16       0.081306      0.001807         0.012814        0.003207    1000
# 17       0.079909      0.004629         0.011340        0.003507    1000
# 18       0.094858      0.006745         0.036884        0.003274    2000
# 19       0.091867      0.009077         0.013071        0.004500    2000
# 20       0.098092      0.013777         0.013541        0.005181    2000
# 21       0.091342      0.007970         0.040354        0.001631    2000
# 22       0.086479      0.008742         0.014750        0.003865    2000
# 23       0.102098      0.009527         0.005748        0.003416    2000
# 24       0.104279      0.006061         0.037374        0.006278    3000
# 25       0.082075      0.001350         0.015694        0.003872    3000
# 26       0.113278      0.027370         0.010629        0.003508    3000
# 27       0.099347      0.007807         0.032017        0.011394    3000
# 28       0.083233      0.003144         0.014049        0.002497    3000
# 29       0.095861      0.020619         0.004416        0.004214    3000
#
#    param_gamma param_kernel  \
# 0         auto          rbf
# 1         auto      sigmoid
# 2         auto       linear
# 3        scale          rbf
# 4        scale      sigmoid
# 5        scale       linear
# 6         auto          rbf
# 7         auto      sigmoid
# 8         auto       linear
# 9        scale          rbf
# 10       scale      sigmoid
# 11       scale       linear
# 12        auto          rbf
# 13        auto      sigmoid
# 14        auto       linear
# 15       scale          rbf
# 16       scale      sigmoid
# 17       scale       linear
# 18        auto          rbf
# 19        auto      sigmoid
# 20        auto       linear
# 21       scale          rbf
# 22       scale      sigmoid
# 23       scale       linear
# 24        auto          rbf
# 25        auto      sigmoid
# 26        auto       linear
# 27       scale          rbf
# 28       scale      sigmoid
# 29       scale       linear
#
#                                                params  split0_test_score  \
# 0         {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}          -0.004176
# 1     {'C': 10, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.044787
# 2      {'C': 10, 'gamma': 'auto', 'kernel': 'linear'}           0.387624
# 3        {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}          -0.003956
# 4    {'C': 10, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.043946
# 5     {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}           0.387624
# 6        {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'}           0.303414
# 7    {'C': 100, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.492088
# 8     {'C': 100, 'gamma': 'auto', 'kernel': 'linear'}           0.596232
# 9       {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}           0.304939
# 10  {'C': 100, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.491855
# 11   {'C': 100, 'gamma': 'scale', 'kernel': 'linear'}           0.596232
# 12      {'C': 1000, 'gamma': 'auto', 'kernel': 'rbf'}           0.731430
# 13  {'C': 1000, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.232428
# 14   {'C': 1000, 'gamma': 'auto', 'kernel': 'linear'}           0.686126
# 15     {'C': 1000, 'gamma': 'scale', 'kernel': 'rbf'}           0.732079
# 16  {'C': 1000, 'gamma': 'scale', 'kernel': 'sigmo...           0.248266
# 17  {'C': 1000, 'gamma': 'scale', 'kernel': 'linear'}           0.686126
# 18      {'C': 2000, 'gamma': 'auto', 'kernel': 'rbf'}           0.788746
# 19  {'C': 2000, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.656854
# 20   {'C': 2000, 'gamma': 'auto', 'kernel': 'linear'}           0.669958
# 21     {'C': 2000, 'gamma': 'scale', 'kernel': 'rbf'}           0.789144
# 22  {'C': 2000, 'gamma': 'scale', 'kernel': 'sigmo...          -0.370980
# 23  {'C': 2000, 'gamma': 'scale', 'kernel': 'linear'}           0.669958
# 24      {'C': 3000, 'gamma': 'auto', 'kernel': 'rbf'}           0.795104
# 25  {'C': 3000, 'gamma': 'auto', 'kernel': 'sigmoid'}          -1.795299
# 26   {'C': 3000, 'gamma': 'auto', 'kernel': 'linear'}           0.669819
# 27     {'C': 3000, 'gamma': 'scale', 'kernel': 'rbf'}           0.795353
# 28  {'C': 3000, 'gamma': 'scale', 'kernel': 'sigmo...          -1.651895
# 29  {'C': 3000, 'gamma': 'scale', 'kernel': 'linear'}           0.669819
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.022594          -0.118956          -0.082926
# 1            0.081689          -0.072355          -0.027541
# 2            0.461268           0.288301           0.340540
# 3            0.022453          -0.119035          -0.082925
# 4            0.082230          -0.072132          -0.027546
# 5            0.461268           0.288301           0.340540
# 6            0.319385           0.155546           0.208414
# 7            0.545107           0.438714           0.468576
# 8            0.635776           0.566816           0.588799
# 9            0.318480           0.155033           0.208422
# 10           0.544604           0.439299           0.468556
# 11           0.635776           0.566816           0.588799
# 12           0.716349           0.686476           0.710172
# 13           0.306815           0.236688           0.291707
# 14           0.598398           0.586104           0.573860
# 15           0.715992           0.686057           0.710177
# 16           0.377692           0.315321           0.291779
# 17           0.598398           0.586104           0.573860
# 18           0.764261           0.818616           0.794131
# 19          -0.432695          -0.346330          -0.484052
# 20           0.592446           0.586953           0.572862
# 21           0.764022           0.818319           0.794133
# 22          -0.421011          -0.350248          -0.483750
# 23           0.592446           0.586953           0.572862
# 24           0.772917           0.846181           0.811601
# 25          -1.629662          -1.461919          -1.712710
# 26           0.588893           0.587076           0.572849
# 27           0.772801           0.846034           0.811601
# 28          -2.010670          -1.468842          -1.712109
# 29           0.588893           0.587076           0.572849
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0           -0.103473        -0.057387        0.056205               25
# 1           -0.051470        -0.004978        0.058648               24
# 2            0.297825         0.355112        0.063693               17
# 3           -0.103510        -0.057395        0.056230               26
# 4           -0.051337        -0.004968        0.058595               23
# 5            0.297825         0.355112        0.063693               17
# 6            0.161756         0.229703        0.069348               21
# 7            0.425516         0.474000        0.042447               15
# 8            0.537415         0.585008        0.032600               13
# 9            0.161488         0.229672        0.069604               22
# 10           0.424226         0.473708        0.042461               16
# 11           0.537415         0.585008        0.032600               13
# 12           0.613293         0.691544        0.041718                5
# 13           0.346868         0.282901        0.043415               20
# 14           0.556109         0.600119        0.045217                7
# 15           0.613122         0.691485        0.041876                6
# 16           0.346175         0.315846        0.044478               19
# 17           0.556109         0.600119        0.045217                7
# 18           0.709676         0.775086        0.036986                3
# 19          -0.076409        -0.399268        0.190629               28
# 20           0.556109         0.595666        0.039218                9
# 21           0.709586         0.775041        0.036992                4
# 22          -0.087414        -0.342681        0.135687               27
# 23           0.556109         0.595666        0.039218                9
# 24           0.725697         0.790300        0.040188                1
# 25          -0.929359        -1.505790        0.308601               29
# 26           0.557014         0.595130        0.039068               11
# 27           0.725615         0.790281        0.040189                2
# 28          -0.961821        -1.561068        0.346643               30
# 29           0.557014         0.595130        0.039068               11

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 80
# BMI: 80
# Children: 80
# Sex Male 0 or 1: 0
# Smoker Yes 0 or 1: 0

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])# change the paramter,play with it.
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[16390.90477909]
