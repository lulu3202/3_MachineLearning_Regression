# %%
#importing the Libraies
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Reading the Dataset
dataset = pd.read_csv('insurance_pre.csv')

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400     False        True
# 1      18  33.770         1   1725.55230      True       False
# 2      28  33.000         3   4449.46200      True       False
# 3      33  22.705         0  21984.47061      True       False
# 4      32  28.880         0   3866.85520      True       False
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830      True       False
# 1334   18  31.920         0   2205.98080     False       False
# 1335   18  36.850         0   1629.83350     False       False
# 1336   21  25.800         0   2007.94500     False       False
# 1337   61  29.070         0  29141.36030     False        True
#
# [1338 rows x 6 columns]

# %%
indep=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dep=dataset['charges']

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
param_grid = {'criterion':['squared_error','absolute_error','friedman_mse','poisson'],
              'max_features': ['auto','sqrt','log2'],
              'splitter':['best','random']} 



grid = GridSearchCV(DecisionTreeRegressor(), param_grid, refit = True, verbose = 3,n_jobs=-1) 
   
# fitting the model for grid search 
grid.fit(indep, dep)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# C:\Anaconda\Lib\site-packages\sklearn\model_selection\_validation.py:547: FitFailedWarning:
# 40 fits failed out of a total of 120.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 32 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Anaconda\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Anaconda\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Anaconda\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Anaconda\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 8 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Anaconda\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Anaconda\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Anaconda\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Anaconda\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Anaconda\Lib\site-packages\sklearn\model_selection\_search.py:1051: UserWarning: One or more of the test scores are non-finite: [       nan        nan 0.68924353 0.5691079  0.68931145 0.64237983
#         nan        nan 0.62437067 0.69383518 0.69401958 0.6511069
#         nan        nan 0.67592757 0.64207434 0.69806617 0.62792413
#         nan        nan 0.64370309 0.63170759 0.63760034 0.62852473]
#   warnings.warn(
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse', 'poisson'],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
# print best parameter after tuning 
#print(grid.best_params_) 
re=grid.cv_results_
#print(re)
grid_predictions = grid.predict(indep) 
   
# print classification report 
from sklearn.metrics import r2_score
r_score=r2_score(dep,grid_predictions)

print("The R_score value for best parameter {}:".format(grid.best_params_),r_score)
# Out:
# The R_score value for best parameter {'criterion': 'friedman_mse', 'max_features': 'log2', 'splitter': 'best'}: 0.998667156135576

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.006886      0.006033         0.000000        0.000000
# 1        0.002806      0.002720         0.000000        0.000000
# 2        0.013395      0.008207         0.004337        0.008164
# 3        0.009910      0.005615         0.005135        0.005931
# 4        0.025174      0.013572         0.005499        0.006019
# 5        0.010140      0.006014         0.006647        0.008145
# 6        0.001603      0.003206         0.000000        0.000000
# 7        0.001536      0.001284         0.000000        0.000000
# 8        0.090188      0.027942         0.003129        0.006258
# 9        0.061958      0.005997         0.001000        0.002001
# 10       0.074897      0.008811         0.003063        0.006127
# 11       0.074023      0.014333         0.009311        0.006331
# 12       0.004576      0.005776         0.000000        0.000000
# 13       0.000503      0.001006         0.000000        0.000000
# 14       0.015635      0.000584         0.011932        0.008262
# 15       0.029063      0.031594         0.010000        0.002524
# 16       0.016320      0.008520         0.009009        0.003130
# 17       0.019072      0.009873         0.004607        0.001327
# 18       0.004523      0.003841         0.000000        0.000000
# 19       0.002531      0.003417         0.000000        0.000000
# 20       0.017790      0.002482         0.007665        0.004999
# 21       0.013697      0.005590         0.004981        0.004697
# 22       0.015547      0.001144         0.002070        0.001416
# 23       0.011231      0.003277         0.004831        0.009258
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               auto           best
# 1    squared_error               auto         random
# 2    squared_error               sqrt           best
# 3    squared_error               sqrt         random
# 4    squared_error               log2           best
# 5    squared_error               log2         random
# 6   absolute_error               auto           best
# 7   absolute_error               auto         random
# 8   absolute_error               sqrt           best
# 9   absolute_error               sqrt         random
# 10  absolute_error               log2           best
# 11  absolute_error               log2         random
# 12    friedman_mse               auto           best
# 13    friedman_mse               auto         random
# 14    friedman_mse               sqrt           best
# 15    friedman_mse               sqrt         random
# 16    friedman_mse               log2           best
# 17    friedman_mse               log2         random
# 18         poisson               auto           best
# 19         poisson               auto         random
# 20         poisson               sqrt           best
# 21         poisson               sqrt         random
# 22         poisson               log2           best
# 23         poisson               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...                NaN
# 1   {'criterion': 'squared_error', 'max_features':...                NaN
# 2   {'criterion': 'squared_error', 'max_features':...           0.746023
# 3   {'criterion': 'squared_error', 'max_features':...           0.616521
# 4   {'criterion': 'squared_error', 'max_features':...           0.623597
# 5   {'criterion': 'squared_error', 'max_features':...           0.634530
# 6   {'criterion': 'absolute_error', 'max_features'...                NaN
# 7   {'criterion': 'absolute_error', 'max_features'...                NaN
# 8   {'criterion': 'absolute_error', 'max_features'...           0.680176
# 9   {'criterion': 'absolute_error', 'max_features'...           0.769642
# 10  {'criterion': 'absolute_error', 'max_features'...           0.658356
# 11  {'criterion': 'absolute_error', 'max_features'...           0.664372
# 12  {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 13  {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.726095
# 15  {'criterion': 'friedman_mse', 'max_features': ...           0.691966
# 16  {'criterion': 'friedman_mse', 'max_features': ...           0.737135
# 17  {'criterion': 'friedman_mse', 'max_features': ...           0.689404
# 18  {'criterion': 'poisson', 'max_features': 'auto...                NaN
# 19  {'criterion': 'poisson', 'max_features': 'auto...                NaN
# 20  {'criterion': 'poisson', 'max_features': 'sqrt...           0.715229
# 21  {'criterion': 'poisson', 'max_features': 'sqrt...           0.622414
# 22  {'criterion': 'poisson', 'max_features': 'log2...           0.695664
# 23  {'criterion': 'poisson', 'max_features': 'log2...           0.690692
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0                 NaN                NaN                NaN
# 1                 NaN                NaN                NaN
# 2            0.544283           0.679252           0.754426
# 3            0.514055           0.549338           0.559181
# 4            0.604182           0.719519           0.726601
# 5            0.522359           0.663439           0.705464
# 6                 NaN                NaN                NaN
# 7                 NaN                NaN                NaN
# 8            0.497661           0.556507           0.659140
# 9            0.603553           0.704271           0.696305
# 10           0.611064           0.724925           0.729766
# 11           0.553135           0.686436           0.696013
# 12                NaN                NaN                NaN
# 13                NaN                NaN                NaN
# 14           0.573018           0.730225           0.603403
# 15           0.511630           0.672336           0.652042
# 16           0.641603           0.716283           0.720563
# 17           0.608600           0.491664           0.694026
# 18                NaN                NaN                NaN
# 19                NaN                NaN                NaN
# 20           0.622083           0.485842           0.662484
# 21           0.569785           0.645398           0.696186
# 22           0.500473           0.753319           0.699801
# 23           0.550578           0.583641           0.681553
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0                 NaN              NaN             NaN               17
# 1                 NaN              NaN             NaN               17
# 2            0.722234         0.689244        0.077038                5
# 3            0.606444         0.569108        0.037847               16
# 4            0.772658         0.689311        0.064522                4
# 5            0.686108         0.642380        0.064501                9
# 6                 NaN              NaN             NaN               17
# 7                 NaN              NaN             NaN               17
# 8            0.728370         0.624371        0.084617               15
# 9            0.695404         0.693835        0.052943                3
# 10           0.745986         0.694020        0.051161                2
# 11           0.655578         0.651107        0.051106                7
# 12                NaN              NaN             NaN               17
# 13                NaN              NaN             NaN               17
# 14           0.746896         0.675928        0.072597                6
# 15           0.682397         0.642074        0.066552               10
# 16           0.674747         0.698066        0.034917                1
# 17           0.655927         0.627924        0.074664               14
# 18                NaN              NaN             NaN               17
# 19                NaN              NaN             NaN               17
# 20           0.732877         0.643703        0.088100                8
# 21           0.624755         0.631708        0.040778               12
# 22           0.538744         0.637600        0.099204               11
# 23           0.636159         0.628525        0.054452               13

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 50
# BMI: 90
# Children: 0
# Sex Male 0 or 1: 0
# Smoker Yes 0 or 1: 0

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])# change the paramter,play with it.
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[9541.69555]
# C:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(

# %%
#regressor = DecisionTreeRegressor()

# %%
import pickle
filename="best_model_decisiontree.sav"
pickle.dump(grid,open(filename,'wb'))

# %%
#provide all 5 inputs as we trained with a model that had 5 input variables
loaded_model=pickle.load(open("best_model_decisiontree.sav",'rb'))
result=loaded_model.predict([[1234,345,4565,1,0]])
# Out:
# C:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
